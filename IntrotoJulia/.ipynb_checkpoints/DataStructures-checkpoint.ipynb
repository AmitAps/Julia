# %% [markdown]
# # Data structures
#
# 1. Dictionaries
# 2. Tuples
# 3. Arrays

# %%
myphonebook = Dict("Amit" => "9599404844", "Vinay" => "9599404844")
# Out:
# Dict{String, String} with 2 entries:
#   "Amit"  => "9599404844"
#   "Vinay" => "9599404844"

# %%
myphonebook["Lalan Singh"] = "9955636976"
# Out:
# "9955636976"

# %%
myphonebook
# Out:
# Dict{String, String} with 3 entries:
#   "Amit"        => "9599404844"
#   "Lalan Singh" => "9955636976"
#   "Vinay"       => "9599404844"

# %%
myphonebook["Amit"]
# Out:
# "9599404844"

# %%
pop!(myphonebook, "Amit")
# Out:
# "9599404844"

# %%
myphonebook
# Out:
# Dict{String, String} with 2 entries:
#   "Lalan Singh" => "9955636976"
#   "Vinay"       => "9599404844"

# %% [markdown]
# ## Unlike tuples and arrays, dictionaries are not ordered. So, we can't index into them.

# %%
myphonebook[1]
# Out:
# KeyError: key 1 not found
#
# Stacktrace:
#  [1] getindex(h::Dict{String, String}, key::Int64)
#    @ Base ./dict.jl:477
#  [2] top-level scope
#    @ In[7]:1
#  [3] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %% [markdown]
# # Tuples

# %%
myfavoriteanimals = ("penguines", "cats", "sugargaliders")
# Out:
# ("penguines", "cats", "sugargaliders")

# %%
myfavoriteanimals[1]
# Out:
# "penguines"

# %% [markdown]
# ## Tuples are immutable, we can't update it

# %%
myfavoriteanimals[1] = "otters"
# Out:
# MethodError: no method matching setindex!(::Tuple{String, String, String}, ::String, ::Int64)
# The function `setindex!` exists, but no method is defined for this combination of argument types.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[10]:1
#  [2] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %% [markdown]
# # Arrays

# %%
myfriends = ["Mukul", "Hanu", "Aditya", "Sakshi"]
# Out:
# 4-element Vector{String}:
#  "Mukul"
#  "Hanu"
#  "Aditya"
#  "Sakshi"

# %%
fibonacci = [1, 1, 2, 3, 5, 8, 13]
# Out:
# 7-element Vector{Int64}:
#   1
#   1
#   2
#   3
#   5
#   8
#  13

# %%
myfriends[1]
# Out:
# "Mukul"

# %%
myfriends[4] = "Julia"
# Out:
# "Julia"

# %%
myfriends
# Out:
# 4-element Vector{String}:
#  "Mukul"
#  "Hanu"
#  "Aditya"
#  "Julia"

# %%
mix = [1, 1.0, "aps", "😄"]
# Out:
# 4-element Vector{Any}:
#  1
#  1.0
#   "aps"
#   "😄"

# %%
push!(fibonacci, 21)
# Out:
# 8-element Vector{Int64}:
#   1
#   1
#   2
#   3
#   5
#   8
#  13
#  21

# %%
pop!(fibonacci)
# Out:
# 21

# %%
fibonacci
# Out:
# 7-element Vector{Int64}:
#   1
#   1
#   2
#   3
#   5
#   8
#  13

# %%
rand(4, 3)
# Out:
# 4×3 Matrix{Float64}:
#  0.688899  0.358301  0.794889
#  0.352939  0.173895  0.375313
#  0.283475  0.104164  0.544447
#  0.835698  0.688836  0.0870118

# %%
numbers = [[1,2,3], [3,4,5],[6,4,5]]
# Out:
# 3-element Vector{Vector{Int64}}:
#  [1, 2, 3]
#  [3, 4, 5]
#  [6, 4, 5]

# %%
rand(4, 3)
# Out:
# 4×3 Matrix{Float64}:
#  0.740718  0.72923    0.716857
#  0.660238  0.438641   0.557145
#  0.419271  0.0608267  0.879687
#  0.843198  0.581206   0.353147

# %%
rand(4, 3, 2)
# Out:
# 4×3×2 Array{Float64, 3}:
# [:, :, 1] =
#  0.645072  0.593126  0.0630926
#  0.575854  0.687986  0.851785
#  0.836943  0.396654  0.0555284
#  0.491974  0.881434  0.791294
#
# [:, :, 2] =
#  0.764394  0.94757   0.590322
#  0.232619  0.788708  0.767222
#  0.77371   0.188563  0.523214
#  0.563092  0.154848  0.108649
