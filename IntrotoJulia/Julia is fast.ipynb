# %%
a = rand(10^7)
# Out:
# 10000000-element Vector{Float64}:
#  0.9855860830926075
#  0.9968600704477617
#  0.1941886529499367
#  0.9392268136080353
#  0.9289786570084727
#  0.28505207489602113
#  0.3653947800759427
#  0.7396473477435531
#  0.4400134896804735
#  0.2808555964629794
#  0.49641363732663557
#  0.24919032878059721
#  0.6754921706415193
#  ⋮
#  0.6902613052279082
#  0.4583147163387703
#  0.006356051913985916
#  0.8291172034535452
#  0.2865015861098542
#  0.8501691769665769
#  0.7218943320092407
#  0.579736401856012
#  0.5834459123593015
#  0.4891989780984568
#  0.9540075212383404
#  0.45092313085049895

# %%
sum(a)
# Out:
# 5.000243811787168e6

# %%
using Pkg
Pkg.add("BenchmarkTools")
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `~/.julia/environments/v1.12/Project.toml`
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`
# Precompiling packages...
#    1735.0 ms  ✓ EpollShim_jll
#    1744.3 ms  ✓ LLVMOpenMP_jll
#    1760.8 ms  ✓ Xorg_libICE_jll
#    1814.9 ms  ✓ Bzip2_jll
#    1823.7 ms  ✓ Xorg_libXau_jll
#    1885.1 ms  ✓ libpng_jll
#    1922.5 ms  ✓ Libmount_jll
#    2014.1 ms  ✓ Graphite2_jll
#    1992.0 ms  ✓ libfdk_aac_jll
#    1748.3 ms  ✓ LERC_jll
#    1816.8 ms  ✓ fzf_jll
#    2070.1 ms  ✓ LAME_jll
#    1892.0 ms  ✓ mtdev_jll
#    1992.6 ms  ✓ XZ_jll
#    1900.2 ms  ✓ Xorg_libXdmcp_jll
#    2030.9 ms  ✓ Ogg_jll
#    2158.4 ms  ✓ x265_jll
#    2355.0 ms  ✓ JpegTurbo_jll
#    2021.3 ms  ✓ x264_jll
#    1987.8 ms  ✓ Zstd_jll
#    1819.6 ms  ✓ LZO_jll
#    1838.9 ms  ✓ Opus_jll
#    1973.3 ms  ✓ libaom_jll
#    2087.2 ms  ✓ Expat_jll
#    1974.6 ms  ✓ Xorg_xtrans_jll
# ...

# %%
using BenchmarkTools
