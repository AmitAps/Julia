# %% [markdown]
# ## This is a note
#
# Julia String

# %%
s1 = "I am a string"
# Out:
# "I am a string"

# %%
s2 = """I am also a string!"""
# Out:
# "I am also a string!"

# %%
"Here, we get an "error" because it's ambiguous where this string."
# Out:
# ParseError:
# # Error @ ]8;;file:///home/aps/Julia/IntrotoJulia/In[3]#1:19\In[3]:1:19]8;;\
# "Here, we get an "error" because it's ambiguous where this string."
# #                 └ ── cannot juxtapose string literal
#
# Stacktrace:
#  [1] top-level scope
#    @ In[3]:1
#  [2] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
"""Look, Mom, no "errors" !!!"""
# Out:
# "Look, Mom, no \"errors\" !!!"

# %% [markdown]
# Note that ' ' define a character and not a string

# %%
typeof('a')
# Out:
# Char

# %%
'We will et an error!'
# Out:
# ParseError:
# # Error @ ]8;;file:///home/aps/Julia/IntrotoJulia/In[6]#1:2\In[6]:1:2]8;;\
# 'We will et an error!'
# #└──────────────────┘ ── character literal contains multiple characters
#
# Stacktrace:
#  [1] top-level scope
#    @ In[6]:1
#  [2] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %% [markdown]
# # String interpolation
# ### We can use $ sign to insert existing variables into a string

# %%
name = "Amit"
my_age = 30
my_dob = 1993
println("This is $name !. I am $my_age years old!. My Birth year $my_dob !")
# Out:
# This is Amit !. I am 30 years old!. My Birth year 1993 !

# %% [markdown]
# # String concatenation
#
# The first way is to use the `string()` function.
#
# `String()` converts non-string input to strings.

# %%
string("How many cats ", "are too many cats?")
# Out:
# "How many cats are too many cats?"

# %%
string("I don't know, but ", 10 , "are too few.")
# Out:
# "I don't know, but 10are too few."

# %%
s3 = "How many cats ";
s4 = "are too many cats?";

# %%
s3*s4
# Out:
# "How many cats are too many cats?"

# %%
"$s3$s4"
# Out:
# "How many cats are too many cats?"
