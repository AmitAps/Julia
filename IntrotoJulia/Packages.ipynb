# %% [markdown]
# # Packages
#
# ### The first time you use a package on a given installation, you need to yse the package manager to cxplicitly add it:

# %%
using Pkg
Pkg.add("Example")
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `~/.julia/environments/v1.12/Project.toml`
#     Manifest No packages added to or removed from `~/.julia/environments/v1.12/Manifest.toml`

# %%
using Example

# %%
hello("it's me. I was wondering if after all these years you'd like to meet.")
# Out:
# "Hello, it's me. I was wondering if after all these years you'd like to meet."

# %% [markdown]
# ### Lets play with the Colours Package

# %%
Pkg.add("Colors")
# Out:
#    Resolving package versions...
#    Installed Reexport ────────── v1.2.2
#    Installed FixedPointNumbers ─ v0.8.5
#    Installed ColorTypes ──────── v0.12.1
#    Installed Colors ──────────── v0.13.1
#     Updating `~/.julia/environments/v1.12/Project.toml`
#   [5ae59095] + Colors v0.13.1
#     Updating `~/.julia/environments/v1.12/Manifest.toml`
#   [3da002f7] + ColorTypes v0.12.1
#   [5ae59095] + Colors v0.13.1
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [189a3867] + Reexport v1.2.2
# Precompiling packages...
#     719.4 ms  ✓ Reexport
#    5333.8 ms  ✓ FixedPointNumbers
#    3864.9 ms  ✓ ColorTypes
#     733.9 ms  ✓ ColorTypes → StyledStringsExt
#    7240.2 ms  ✓ Colors
#   5 dependencies successfully precompiled in 17 seconds. 47 already precompiled.

# %%
using Colors
