# %%
println("This is Amit and i am doing Julia Programming")
# Out:
# This is Amit and i am doing Julia Programming

# %%
my_answer = 42
typeof(my_answer)
# Out:
# Int64

# %%
my_pi = 3.14159
typeof(my_pi)
# Out:
# Float64

# %%
😺 = "smiley cat!"
typeof(😺)
# Out:
# String

# %%
😺 = 1
# Out:
# 1

# %%
typeof(😺)
# Out:
# Int64

# %%
#You can leave comments on a singe line using the pound/hash key
# 1 + 1
1 + 1
# Out:
# 2

# %%
#= 
For multi-line comments,
use the '#= =#' sequence.
=#

# %%
sum = 3 + 7
# Out:
# 10

# %%
difference = 10 - 3
# Out:
# 7

# %%
quotient = 100 / 10
# Out:
# 10.0

# %%
product = 20 * 5
# Out:
# 100

# %%
power = 10 ^ 2
# Out:
# 100

# %%
modulus = 101 % 2
# Out:
# 1

# %%
days = 365
days_float = convert(Float64, days)
# Out:
# 365.0

# %%
convert(Int64, "1")
# Out:
# MethodError: Cannot `convert` an object of type String to an object of type Int64
# The function `convert` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   convert(::Type{T}, ::CartesianIndex{1}) where T<:Number
#    @ Base multidimensional.jl:139
#   convert(::Type{T}, ::AbstractChar) where T<:Number
#    @ Base char.jl:194
#   convert(::Type{T}, ::Base.TwicePrecision) where T<:Number
#    @ Base twiceprecision.jl:271
#   ...
#
#
# Stacktrace:
#  [1] top-level scope
#    @ In[23]:1
#  [2] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
parse(Int64, "1")
# Out:
# 1
