# %% [markdown]
# # Ploting
#
# ### There are a few different ways to plot in Julia(including calling PyPlot).

# %%
using Pkg
Pkg.add("Plots")
using Plots
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed JpegTurbo_jll ──────────────── v3.1.4+0
#    Installed GR_jll ─────────────────────── v0.73.19+1
#    Installed x265_jll ───────────────────── v4.1.0+0
#    Installed LERC_jll ───────────────────── v4.0.1+0
#    Installed libdecor_jll ───────────────── v0.2.2+0
#    Installed LoggingExtras ──────────────── v1.2.0
#    Installed libfdk_aac_jll ─────────────── v2.0.4+0
#    Installed Libmount_jll ───────────────── v2.41.2+0
#    Installed Opus_jll ───────────────────── v1.5.2+0
#    Installed RelocatableFolders ─────────── v1.0.1
#    Installed Xorg_xkbcomp_jll ───────────── v1.4.7+0
#    Installed ConcurrentUtilities ────────── v2.5.0
#    Installed Measures ───────────────────── v0.3.3
#    Installed Xorg_xcb_util_wm_jll ───────── v0.4.2+0
#    Installed Contour ────────────────────── v0.6.3
#    Installed Grisu ──────────────────────── v1.0.2
# ...

# %%
using Plots

# %%
x = -3:0.1:3
f(x) = x^2

y = f.(x)
# Out:
# 61-element Vector{Float64}:
#  9.0
#  8.41
#  7.839999999999999
#  7.290000000000001
#  6.760000000000001
#  6.25
#  5.76
#  5.289999999999999
#  4.840000000000001
#  4.41
#  4.0
#  3.61
#  3.24
#  ⋮
#  3.61
#  4.0
#  4.41
#  4.840000000000001
#  5.289999999999999
#  5.76
#  6.25
#  6.760000000000001
#  7.290000000000001
#  7.839999999999999
#  8.41
#  9.0

# %% [markdown]
# ### Now let's load the GR background

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
plot(x, y, label="line")
scatter!(x, y, label="points")

# %%
Pkg.add("PlotlyJS")
# Out:
#    Resolving package versions...
#    Installed Hiccup ────────────────────── v0.2.2
#    Installed AssetRegistry ─────────────── v0.1.0
#    Installed PlotlyKaleido ─────────────── v2.3.1
#    Installed Pidfile ───────────────────── v1.3.0
#    Installed PlotlyBase ────────────────── v0.8.22
#    Installed Preferences ───────────────── v1.5.1
#    Installed Kaleido_jll ───────────────── v0.2.1+0
#    Installed TableTraits ───────────────── v1.0.1
#    Installed Blink ─────────────────────── v0.12.9
#    Installed WebIO ─────────────────────── v0.8.21
#    Installed WebSockets ────────────────── v1.6.0
#    Installed Lazy ──────────────────────── v0.15.1
#    Installed Mustache ──────────────────── v1.0.21
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed UnPack ────────────────────── v1.0.2
#    Installed JSExpr ────────────────────── v0.5.4
#    Installed Widgets ───────────────────── v0.6.7
#    Installed PlotlyJS ──────────────────── v0.18.17
# ...

# %%
plotlyjs()
# Out:
# [ Info: Precompiling PlotlyJS [f0f68f2c-4968-5e81-91da-67840de0976a] (cache misses: wrong dep version loaded (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up
# ┌ Warning: Module JSON with build ID fafbfcfd-e4be-8c43-0ab6-352ee75a78be is missing from the cache.
# │ This may mean JSON [682c06a0-de6a-54ab-a142-c8b1cf79cde6] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:2641
# ┌ Info: Skipping precompilation due to precompilable error. Importing PlotlyJS [f0f68f2c-4968-5e81-91da-67840de0976a].
# └   exception = Error when precompiling module, potentially caused by a __precompile__(false) declaration in the module.
# [ Info: Precompiling PlotlyBase [a03496cd-edff-5a9b-9e67-9cda94a718b5] (cache misses: wrong dep version loaded (2))
#
# ...

# %%
globaltemperatures = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
numpirates = [45000, 20000, 15000, 5000, 400, 17]
# Out:
# 6-element Vector{Int64}:
#  45000
#  20000
#  15000
#   5000
#    400
#     17

# %%
# First, plot the data
plot(numpirates, globaltemperatures, legend=false)
scatter!(numpirates, globaltemperatures, legend=false)

# This reverses x axis we can see how the temperature changes as xflip!()

# Add titles and labels
xlabel!("Number of pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")

# %% [markdown]
# ### To create a plot with subplots, we just name each of the individual subpots and then warp those names, along with a layout specification, in another `plot` call.

# %%
p1 = plot(x, x)
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1,p2,p3,p4, layout=(2,2), legend=false)
